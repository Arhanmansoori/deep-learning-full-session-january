# %%
#include<stdio.h>
#include<conio.h>
void main()
{
    printf("hello azad ");
 getch();
}
# Out:
#   File "<ipython-input-3-e63446f99130>", line 3
#     void main()
#             ^
# SyntaxError: invalid syntax
